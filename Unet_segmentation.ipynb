# %% [markdown]
# <a href="https://colab.research.google.com/github/Eng-Abdulmalik/Eng-Abdulmalik/blob/main/Unet_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
from glob import glob
import tensorflow as tf
#from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger
#from unet import build_unet

global image_h
global image_w
global num_classes
global classes
global rgb_codes

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path):
    train_x = sorted(glob(os.path.join(path, "train", "images", "*.tif")))
    train_y = sorted(glob(os.path.join(path, "train", "masks", "*.png")))

    valid_x = sorted(glob(os.path.join(path, "valid", "images", "*.tif")))
    valid_y = sorted(glob(os.path.join(path, "valid", "masks", "*.png")))

    test_x = sorted(glob(os.path.join(path, "test", "images", "*.tif")))
    test_y = sorted(glob(os.path.join(path, "test", "masks", "*.png")))

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image_mask(x, y):
    """ Image """
    x = cv2.imread(x, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (image_w, image_h))
    x = x/255.0
    x = x.astype(np.float32)

    """ Mask """
    y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
    y = cv2.resize(y, (image_w, image_h))
    y = y.astype(np.int32)

    return x, y

def preprocess(x, y):
    def f(x, y):
        x = x.decode()
        y = y.decode()
        return read_image_mask(x, y)

    image, mask = tf.numpy_function(f, [x, y], [tf.float32, tf.int32])
    mask = tf.one_hot(mask, num_classes)

    image.set_shape([image_h, image_w, 3])
    mask.set_shape([image_h, image_w, num_classes])

    return image, mask

def tf_dataset(X, Y, batch=8):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    ds = ds.shuffle(buffer_size=5000).map(preprocess)
    ds = ds.batch(batch).prefetch(2)
    return ds

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("/content/gdrive/My Drive/Data_Ratina/files")

    """ Hyperparameters """
    image_h = 64
    image_w = 64
    num_classes = 3
    input_shape = (image_h, image_w, 3)
    batch_size = 16
    lr = 1e-4 ## 0.0001
    num_epochs = 10

    """ Paths """
    dataset_path = "/content/gdrive/My Drive/Data_Ratina/Drive/"
    model_path = os.path.join("content/gdrive/My Drive/Data/files", "model.h5")
    csv_path = os.path.join("/content/gdrive/My Drive/Data/files", "data.csv")

    """ RGB Code and Classes """
    rgb_codes = [
        [0, 0, 0], [0, 153, 255]
    ]

    classes = [
        "ratina_rgb", "ratina_mask",
    ]

    """ Loading the dataset """
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)
    print(f"Train: {len(train_x)}/{len(train_y)} - Valid: {len(valid_x)}/{len(valid_y)} - Test: {len(test_x)}/{len(test_x)}")
    print("")

    """ Dataset Pipeline """
    train_ds = tf_dataset(train_x, train_y, batch=batch_size)
    valid_ds = tf_dataset(valid_x, valid_y, batch=batch_size)
# Out:
# Train: 38/38 - Valid: 14/14 - Test: 20/20

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_classes):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(num_classes, 1, padding="same", activation="softmax")(d4)

    model = Model(inputs, outputs)
    return model


# if __name__ == "__main__":
#     input_shape = (64, 64, 1)
#     model = build_unet(input_shape, 1)
#     model.summary()

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.losses import binary_crossentropy

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + smooth) / (union + smooth)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def focal_loss(y_true, y_pred):
    alpha=0.25
    gamma=2
    def focal_loss_with_logits(logits, targets, alpha, gamma, y_pred):
        weight_a = alpha * (1 - y_pred) ** gamma * targets
        weight_b = (1 - alpha) * y_pred ** gamma * (1 - targets)
        return (tf.math.log1p(tf.exp(-tf.abs(logits))) + tf.nn.relu(-logits)) * (weight_a + weight_b) + logits * weight_b

    y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
    logits = tf.math.log(y_pred / (1 - y_pred))
    loss = focal_loss_with_logits(logits=logits, targets=y_true, alpha=alpha, gamma=gamma, y_pred=y_pred)
    # or reduce_sum and/or axis=-1
    return tf.reduce_mean(loss)



metrics = [
      dice_coef,
      iou,


  ],

input_shape=(64,64,3)
def get_model():
    return build_unet(input_shape,3)
model = get_model()
#model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)
model.summary()
model.save('/content/gdrive/My Drive/Data/model.h5')
checkpointer = tf.keras.callbacks.ModelCheckpoint('/content/gdrive/My Drive/Data/model.h5', verbose=1, save_best_only=True)


callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=100, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs')]

model.fit(train_ds,
    validation_data=valid_ds,
     batch_size=16,
       epochs=100,
       verbose=1,
    callbacks=callbacks
)
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  conv2d_57 (Conv2D)          (None, 64, 64, 64)           1792      ['input_4[0][0]']
#
#  batch_normalization_54 (Ba  (None, 64, 64, 64)           256       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 64, 64, 64)           256       ['conv2d_58[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  max_pooling2d_12 (MaxPooli  (None, 32, 32, 64)           0         ['activation_55[0][0]']
#  ng2D)
#
#  conv2d_59 (Conv2D)          (None, 32, 32, 128)          73856     ['max_pooling2d_12[0][0]']
#
#  batch_normalization_56 (Ba  (None, 32, 32, 128)          512       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_56[0][0]']
#
#  batch_normalization_57 (Ba  (None, 32, 32, 128)          512       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  max_pooling2d_13 (MaxPooli  (None, 16, 16, 128)          0         ['activation_57[0][0]']
#  ng2D)
#
#  conv2d_61 (Conv2D)          (None, 16, 16, 256)          295168    ['max_pooling2d_13[0][0]']
#
#  batch_normalization_58 (Ba  (None, 16, 16, 256)          1024      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_58[0][0]']
#
#  batch_normalization_59 (Ba  (None, 16, 16, 256)          1024      ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  max_pooling2d_14 (MaxPooli  (None, 8, 8, 256)            0         ['activation_59[0][0]']
#  ng2D)
#
#  conv2d_63 (Conv2D)          (None, 8, 8, 512)            1180160   ['max_pooling2d_14[0][0]']
#
#  batch_normalization_60 (Ba  (None, 8, 8, 512)            2048      ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 8, 8, 512)            2359808   ['activation_60[0][0]']
#
#  batch_normalization_61 (Ba  (None, 8, 8, 512)            2048      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  max_pooling2d_15 (MaxPooli  (None, 4, 4, 512)            0         ['activation_61[0][0]']
#  ng2D)
#
#  conv2d_65 (Conv2D)          (None, 4, 4, 1024)           4719616   ['max_pooling2d_15[0][0]']
#
#  batch_normalization_62 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_66 (Conv2D)          (None, 4, 4, 1024)           9438208   ['activation_62[0][0]']
#
#  batch_normalization_63 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_transpose_12 (Conv2  (None, 8, 8, 512)            2097664   ['activation_63[0][0]']
#  DTranspose)
#
#  concatenate_12 (Concatenat  (None, 8, 8, 1024)           0         ['conv2d_transpose_12[0][0]',
#  e)                                                                  'activation_61[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 8, 8, 512)            4719104   ['concatenate_12[0][0]']
#
#  batch_normalization_64 (Ba  (None, 8, 8, 512)            2048      ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_68 (Conv2D)          (None, 8, 8, 512)            2359808   ['activation_64[0][0]']
#
#  batch_normalization_65 (Ba  (None, 8, 8, 512)            2048      ['conv2d_68[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_transpose_13 (Conv2  (None, 16, 16, 256)          524544    ['activation_65[0][0]']
#  DTranspose)
#
#  concatenate_13 (Concatenat  (None, 16, 16, 512)          0         ['conv2d_transpose_13[0][0]',
#  e)                                                                  'activation_59[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 16, 16, 256)          1179904   ['concatenate_13[0][0]']
#
#  batch_normalization_66 (Ba  (None, 16, 16, 256)          1024      ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_66 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_66[0][0]']
#
#  batch_normalization_67 (Ba  (None, 16, 16, 256)          1024      ['conv2d_70[0][0]']
#  tchNormalization)
#
#  activation_67 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_transpose_14 (Conv2  (None, 32, 32, 128)          131200    ['activation_67[0][0]']
#  DTranspose)
#
#  concatenate_14 (Concatenat  (None, 32, 32, 256)          0         ['conv2d_transpose_14[0][0]',
#  e)                                                                  'activation_57[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 32, 32, 128)          295040    ['concatenate_14[0][0]']
#
#  batch_normalization_68 (Ba  (None, 32, 32, 128)          512       ['conv2d_71[0][0]']
#  tchNormalization)
#
#  activation_68 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_72 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_68[0][0]']
#
#  batch_normalization_69 (Ba  (None, 32, 32, 128)          512       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  activation_69 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  conv2d_transpose_15 (Conv2  (None, 64, 64, 64)           32832     ['activation_69[0][0]']
#  DTranspose)
#
#  concatenate_15 (Concatenat  (None, 64, 64, 128)          0         ['conv2d_transpose_15[0][0]',
#  e)                                                                  'activation_55[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 64, 64, 64)           73792     ['concatenate_15[0][0]']
#
#  batch_normalization_70 (Ba  (None, 64, 64, 64)           256       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  activation_70 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_74 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_70[0][0]']
#
#  batch_normalization_71 (Ba  (None, 64, 64, 64)           256       ['conv2d_74[0][0]']
#  tchNormalization)
#
#  activation_71 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  conv2d_75 (Conv2D)          (None, 64, 64, 3)            195       ['activation_71[0][0]']
#
# ==================================================================================================
# Total params: 31055427 (118.47 MB)
# Trainable params: 31043651 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 56s 13s/step - loss: 0.6728 - dice_coef: 0.5208 - iou: 0.3530 - val_loss: 0.9383 - val_dice_coef: 0.3200 - val_iou: 0.1905
# Epoch 2/100
# 3/3 [==============================] - 26s 8s/step - loss: 0.3719 - dice_coef: 0.6318 - iou: 0.4622 - val_loss: 0.9120 - val_dice_coef: 0.3298 - val_iou: 0.1974
# Epoch 3/100
# 3/3 [==============================] - 24s 7s/step - loss: 0.2539 - dice_coef: 0.7104 - iou: 0.5511 - val_loss: 0.8703 - val_dice_coef: 0.3459 - val_iou: 0.2091
# Epoch 4/100
# 3/3 [==============================] - 25s 7s/step - loss: 0.1941 - dice_coef: 0.7565 - iou: 0.6085 - val_loss: 0.8499 - val_dice_coef: 0.3545 - val_iou: 0.2154
# Epoch 5/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1577 - dice_coef: 0.7877 - iou: 0.6499 - val_loss: 0.8290 - val_dice_coef: 0.3639 - val_iou: 0.2224
# Epoch 6/100
# 3/3 [==============================] - 23s 7s/step - loss: 0.1319 - dice_coef: 0.8093 - iou: 0.6797 - val_loss: 0.8036 - val_dice_coef: 0.3753 - val_iou: 0.2310
# Epoch 7/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.1187 - dice_coef: 0.8204 - iou: 0.6956 - val_loss: 0.7806 - val_dice_coef: 0.3855 - val_iou: 0.2388
# Epoch 8/100
# 3/3 [==============================] - 26s 8s/step - loss: 0.1113 - dice_coef: 0.8279 - iou: 0.7063 - val_loss: 0.7485 - val_dice_coef: 0.3997 - val_iou: 0.2498
# Epoch 9/100
# 3/3 [==============================] - 23s 7s/step - loss: 0.1048 - dice_coef: 0.8341 - iou: 0.7154 - val_loss: 0.7229 - val_dice_coef: 0.4124 - val_iou: 0.2598
# Epoch 10/100
# 3/3 [==============================] - 24s 7s/step - loss: 0.0999 - dice_coef: 0.8379 - iou: 0.7210 - val_loss: 0.6497 - val_dice_coef: 0.4483 - val_iou: 0.2889
# Epoch 11/100
# 3/3 [==============================] - 25s 7s/step - loss: 0.0981 - dice_coef: 0.8403 - iou: 0.7247 - val_loss: 0.6003 - val_dice_coef: 0.4748 - val_iou: 0.3113
# Epoch 12/100
# 3/3 [==============================] - 24s 7s/step - loss: 0.0959 - dice_coef: 0.8440 - iou: 0.7301 - val_loss: 0.5783 - val_dice_coef: 0.4865 - val_iou: 0.3214
# Epoch 13/100
# 3/3 [==============================] - 25s 7s/step - loss: 0.0894 - dice_coef: 0.8493 - iou: 0.7380 - val_loss: 0.5473 - val_dice_coef: 0.5032 - val_iou: 0.3362
# Epoch 14/100
# 3/3 [==============================] - 24s 7s/step - loss: 0.0893 - dice_coef: 0.8486 - iou: 0.7370 - val_loss: 0.5307 - val_dice_coef: 0.5123 - val_iou: 0.3444
# Epoch 15/100
# 3/3 [==============================] - 24s 7s/step - loss: 0.0827 - dice_coef: 0.8565 - iou: 0.7490 - val_loss: 0.5103 - val_dice_coef: 0.5249 - val_iou: 0.3559
# Epoch 16/100
# 3/3 [==============================] - 23s 7s/step - loss: 0.0783 - dice_coef: 0.8596 - iou: 0.7537 - val_loss: 0.4984 - val_dice_coef: 0.5328 - val_iou: 0.3631
# Epoch 17/100
# 3/3 [==============================] - 25s 7s/step - loss: 0.0773 - dice_coef: 0.8613 - iou: 0.7564 - val_loss: 0.5060 - val_dice_coef: 0.5284 - val_iou: 0.3591
# Epoch 18/100
# 1/3 [=========>....................] - ETA: 20s - loss: 0.0730 - dice_coef: 0.8621 - iou: 0.7576

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import f1_score, jaccard_score
#from train import create_dir, load_dataset

global image_h
global image_w
global num_classes
global classes
global rgb_codes

def grayscale_to_rgb(mask, rgb_codes):
    h, w = mask.shape[0], mask.shape[1]
    mask = mask.astype(np.int32)
    output = []

    for i, pixel in enumerate(mask.flatten()):
        output.append(rgb_codes[pixel])

    output = np.reshape(output, (h, w, 3))
    return output

def save_results(image_x, mask, pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = grayscale_to_rgb(mask, rgb_codes)

    pred = np.expand_dims(pred, axis=-1)
    pred = grayscale_to_rgb(pred, rgb_codes)

    line = np.ones((image_x.shape[0], 10, 3)) * 255

    cat_images = np.concatenate([image_x, line, mask, line, pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("/content/gdrive/My Drive/Data/results")

    """ Hyperparameters """
    image_h = 64
    image_w = 64
    num_classes = 1

    """ Paths """
    dataset_path = "/content/gdrive/My Drive/Data_Ratina/Drive/"
    model_path = os.path.join("/content/gdrive/My Drive/Data/model.h5")

    """ RGB Code and Classes """
    rgb_codes = [
        [0, 0, 0], [0, 153, 255],
    ]

    classes = [
        "ratina_rgb", "ratina_mask",
    ]

    """ Loading the dataset """
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)
    print(f"Train: {len(train_x)}/{len(train_y)} - Valid: {len(valid_x)}/{len(valid_y)} - Test: {len(test_x)}/{len(test_x)}")
    print("")

    """ Load the model """
    model = tf.keras.models.load_model(model_path)

    """ Prediction & Evaluation """
    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extract the name """
        name = x.split("/")[-1].split(".")[0]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR)
        image = cv2.resize(image, (image_w, image_h))
        image_x = image
        image = image/255.0 ## (H, W, 3)
        image = np.expand_dims(image, axis=0) ## [1, H, W, 3]
        image = image.astype(np.float32)

        """ Reading the mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (image_w, image_h))
        mask = mask.astype(np.int32)

        """ Prediction """
        pred = model.predict(image, verbose=0)[0]
        pred = np.argmax(pred, axis=-1) ## [0.1, 0.2, 0.1, 0.6] -> 3
        pred = pred.astype(np.int32)

        ## cv2.imwrite("pred.png", pred * (255/11))

        # rgb_mask = grayscale_to_rgb(pred, rgb_codes)
        # cv2.imwrite("pred.png", rgb_mask)

        """ Save the results """
        save_image_path = f"results/{name}.png"
        save_results(image_x, mask, pred, save_image_path)

        """ Flatten the array """
        mask = mask.flatten()
        pred = pred.flatten()

        labels = [i for i in range(num_classes)]

        """ Calculating the metrics values """
        f1_value = f1_score(mask, pred, labels=labels, average=None, zero_division=0)
        jac_value = jaccard_score(mask, pred, labels=labels, average=None, zero_division=0)

        SCORE.append([f1_value, jac_value])

    score = np.array(SCORE)
    score = np.mean(score, axis=0)

    f = open("files/score.csv", "w")
    f.write("Class,F1,Jaccard\n")

    l = ["Class", "F1", "Jaccard"]
    print(f"{l[0]:15s} {l[1]:10s} {l[2]:10s}")
    print("-"*35)

    for i in range(num_classes):
        class_name = classes[i]
        f1 = score[0, i]
        jac = score[1, i]
        dstr = f"{class_name:15s}: {f1:1.5f} - {jac:1.5f}"
        print(dstr)
        f.write(f"{class_name:15s},{f1:1.5f},{jac:1.5f}\n")

    print("-"*35)
    class_mean = np.mean(score, axis=-1)
    class_name = "Mean"

    f1 = class_mean[0]
    jac = class_mean[1]

    dstr = f"{class_name:15s}: {f1:1.5f} - {jac:1.5f}"
    print(dstr)
    f.write(f"{class_name:15s},{f1:1.5f},{jac:1.5f}\n")

    f.close()
# Out:
# Train: 38/38 - Valid: 14/14 - Test: 20/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a0cd6b10a413> in <cell line: 42>()
#      72
#      73     """ Load the model """
# ---> 74     model = tf.keras.models.load_model(model_path)
#      75
#      76     """ Prediction & Evaluation """
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/legacy/serialization.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     535             obj = module_objects.get(object_name)
#     536             if obj is None:
# --> 537                 raise ValueError(
#     538                     f"Unknown {printable_module_name}: '{object_name}'. "
#     539                     "Please ensure you are using a "
#
# ValueError: Unknown metric function: 'dice_coef'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.
